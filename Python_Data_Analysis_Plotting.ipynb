# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from pandas import DataFrame, Series
from matplotlib import pyplot as plt

# %%
np.random.seed(1000)
y = np.random.standard_normal(20)
x = range(len(y))
plt.plot(x,y)

# %%
plt.plot(y.cumsum())

# %%
plt.plot(y.cumsum())
plt.grid(True)
plt.axis('tight')
plt.xlim(-1,20)
plt.ylim(np.min(y.cumsum()-1),
        np.max(y.cumsum()+1))
# Out:
# (-3.1915310617211072, 1.4342209788376488)

# %%
plt.figure(figsize=(12,6))
plt.plot(y.cumsum(),'b',lw=1.5,marker='o')
#plt.plot(y.cumsum(),'ks') # this plots the second dots, first is color code second is marker code
plt.grid(True)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.xlim(-1,20)
plt.ylim(np.min(y.cumsum()-1),
        np.max(y.cumsum()+1))
# Out:
# (-3.1915310617211072, 1.4342209788376488)

# %%
# create an empty matplot Figure with 3 subplots

fig = plt.figure(1)
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
plt.plot([1.5,3.5,-2,1.6])

# %%
# a line with black dashes, using a style option
from numpy.random import randn
plt.plot(randn(50).cumsum(),'k--')

# %%
fig = plt.figure(1)
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
_ = ax1.hist(randn(100),bins=20,color='k',alpha=0.3)
ax2.scatter(np.arange(30),np.arange(30)+3*randn(30))
ax3.plot(randn(50).cumsum(),'k--')

# %%
# since creating subplots is so common, this method returns
# an array containing the created subplot objects

fig, axes = plt.subplots(2,1,sharex=True,sharey=True)

# %%
data = randn(30).cumsum()

fig, axes = plt.subplots(1,1)
#plt.legend(loc='best')
axes.plot(data,'k-', drawstyle='steps-post',
          label='step-post')
axes.plot(data,'k--', label='default')
axes.legend(loc='best')
axes.set_title('My First Graph')
axes.set_xticks([1,10,50])

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
# setup Lambert Conformal basemap.
m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution='c',lat_1=45.,lat_2=55,lat_0=50,lon_0=-107.)
# draw coastlines.
m.drawcoastlines()
# draw a boundary around the map, fill the background.
# this background will end up being the ocean color, since
# the continents will be drawn on top.
m.drawmapboundary(fill_color='white')
# fill continents, set lake color same as ocean color.
m.fillcontinents(color='coral',lake_color='red')
plt.show()
